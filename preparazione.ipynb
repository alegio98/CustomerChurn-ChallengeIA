# %%
# !pip install tensorflow
# !pip install pandas
# !pip install -U scikit-learn scipy matplotlib
# Out:
# WARNING: Value for scheme.platlib does not match. Please report this to <https://github.com/pypa/pip/issues/9617>
# distutils: /usr/local/lib/python3.8/dist-packages
# sysconfig: /usr/lib/python3.8/site-packages
# WARNING: Value for scheme.purelib does not match. Please report this to <https://github.com/pypa/pip/issues/9617>
# distutils: /usr/local/lib/python3.8/dist-packages
# sysconfig: /usr/lib/python3.8/site-packages
# WARNING: Value for scheme.headers does not match. Please report this to <https://github.com/pypa/pip/issues/9617>
# distutils: /usr/local/include/python3.8/UNKNOWN
# sysconfig: /usr/include/python3.8
# WARNING: Value for scheme.scripts does not match. Please report this to <https://github.com/pypa/pip/issues/9617>
# distutils: /usr/local/bin
# sysconfig: /usr/bin
# WARNING: Value for scheme.data does not match. Please report this to <https://github.com/pypa/pip/issues/9617>
# distutils: /usr/local
# sysconfig: /usr
# WARNING: Additional context:
# user = False
# ...

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split

#lavoro su questo insieme di dati 
dati = pd.read_csv("./Churn_Modelling.partial.csv")

# %%
#stampa delle prime 5 righe dei dati 
dati.head()
# Out:
#    Exited  RowNumber  CustomerId   Surname  CreditScore Geography  Gender  \
# 0       0       9255    15601116      P'an          686    France    Male
# 1       0       1562    15766374      Leak          632   Germany    Male
# 2       1       1671    15716994     Green          559     Spain    Male
# 3       1       6088    15730759  Chukwudi          561    France  Female
# 4       1       6670    15797900  Chinomso          517    France    Male
#
#    Age  Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0   32       6       0.00              2          1               1
# 1   42       4  119624.60              2          1               1
# 2   24       3  114739.92              1          1               0
# 3   27       9  135637.00              1          1               0
# 4   56       9  142147.32              1          0               0
#
#    EstimatedSalary
# 0        179093.26
# 1        195978.86
# 2         85891.02
# 3        153080.40
# ...

# %%
train , test = train_test_split(dati , random_state=42)
train.to_csv("train.csv", index=False)
test.to_csv("test.csv", index=False)

# %% [markdown]
# Ho provveduto a suddividere il dataset in set di dati di test e di allenamento.

# %% [markdown]
# #### Made by Alessandro Giovannini 520310
